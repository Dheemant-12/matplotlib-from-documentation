# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,ax = plt.subplots()
#ax.plot([1,2,3,4],[1,2,3,4])
#plt.show()#standard line of code for showing a plotted graph
ax.plot([1,4,8,9],[2,6,7,0])
plt.show()

# %% [markdown]
# #Figure
# The whole figure. The Figure keeps track of all the child Axes, a group of 'special' Artists (titles, figure legends, colorbars, etc.), and even nested subfigures.

# %%
#fig = plt.figure() # this creates and empty axes figure
fig,ax = plt.subplots() # 2 axes x and y but no plotting in it, it's like an empty graph
fig,ax = plt.subplots(2,2) #this creates a 2x2 grid
fig, axs = plt.subplot_mosaic([['left', 'right_top'],['left', 'right_bottom']]) # one with vertical tall one and other 2 normla form 2x2 grid

# %% [markdown]
# #Various Inputs
# Sometimes few inputs like matrix and pandas data objects cannot be useful for plotting a graph so we need to convert those into arrays

# %%
b = np.matrix([[1,2],[3,4]])
b_asarray = np.asarray(b)

# %%
np.random.seed(19680801)  # fixed random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %% [markdown]
# #Coding styles
# Getting two similar outputs , but different coding formats

# %%
#OO-style
x=np.linspace(0,2,100) #sample data
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.plot(x,x,label='linear')
ax.plot(x,x**2,label = 'quadratic')
ax.plot(x,x**3,label = 'cubic')
ax.set_xlabel('x-label')#setting x-axis label
ax.set_ylabel('y-label')#setting y-axis label
ax.set_title('Simple Plot')# adding title
ax.legend()# legend adding in fig, legend automatically understands the graph and makes an own legend itself

#pyplot - style
x = np.linspace(0, 2, 100)  # Sample data.
plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) Axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

#As we can notice it is the same graph but difference is code defines its style

# %% [markdown]
# #Making Helper Functions
# If you need to make same plots over and over again with different data sets, or want easily wrap matplotlib methods

# %%
import numpy as np
import matplotlib.pyplot as plt

def my_plotter(ax, data1, data2, param_dict):
    out = ax.plot(data1, data2, **param_dict)
    return out

data1, data2, data3, data4 = np.random.randn(4, 100)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(8, 2.7))

my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})
my_plotter(ax3, data2, data4, {'marker': 'P'})

plt.tight_layout()
plt.show()

# %% [markdown]
# #Styling Artists
# We set the line width,shape , color accoridng to our favourtism

# %%
fig,ax = plt.subplots(figsize = (5,2.7))
x = np.arange(len(data1))
ax.plot(x,np.cumsum(data1),color='blue',linewidth =3 , linestyle='--')
l, = ax.plot(x,np.cumsum(data2),color='orange',linewidth = 1,)
l.set_linestyle(':')
ax.plot(x, np.cumsum(data3),color='black',linewidth=2,linestyle='-.')
plt.show()

# %% [markdown]
# #Colors
# Matplotlib has a very flexible array of colors that are accepted for most Artists; see allowable color definitions for a list of specifications

# %%
fig,ax = plt.subplots(figsize=(5,2.7))
ax.scatter(data1,data2,s=50,facecolors='C0',edgecolors='k')
ax.scatter(data3,data4,s=50,facecolors='C1',edgecolors='k')

# %% [markdown]
# #Linewidths, linestyles, and markersizes
# Line widths are typically in typographic points (1 pt = 1/72 inch) and available for Artists that have stroked lines. Similarly, stroked lines can have a linestyle

# %%
fig,ax = plt.subplots(figsize=(5,2.7))
ax.plot(data1,'o',label='data1')
ax.plot(data2,'d',label='data2')
ax.plot(data3,'v',label='data3')
ax.plot(data4,'s',label='data4')
ax.legend()

# %% [markdown]
# #Axes,labels and text
# set_xlabel, set_ylabel, and set_title are used to add text in the indicated locations (see Text in Matplotlib for more discussion). Text can also be directly added to plots using text

# %%
mu,sigma = 115,15
x = mu+sigma*np.random.randn(10000)
fig,ax = plt.subplots(figsize=(5,2.7),layout='constrained')
ax.hist(x,50,density=True,facecolor='C0',alpha = 0.75) # the histogram of data
ax.set_xlabel('Length [cm]')
ax.set_ylabel('Probability')
ax.set_title('Aardvark lengths\n (not really)') # using mathematical text inside a graph
ax.text(75,0.025,r'$\mu=115,\ \sigma=15$')
ax.axis([55,175,0,0.03])
ax.grid(True)

# %% [markdown]
# #Annotations
# We can also annotate points on a plot, often by connecting an arrow pointing to xy

# %%
fig,ax = plt.subplots(figsize=(5,2.7))
t=np.arange(0.0,5.0,0.01)
s=np.cos(2*np.pi*t)
line, = ax.plot(t,s,lw=2)
ax.annotate('local max',xy=(2,1),xytext=(3,1.5),
            arrowprops=dict(facecolor='black',shrink=0.05))
ax.set_ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %% [markdown]
# #Legends
# we use them as a marker to the data displayed in the graph

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(np.arange(len(data1)), data1, label='data1')
ax.plot(np.arange(len(data2)), data2, label='data2')
ax.plot(np.arange(len(data3)), data3, 'o', label='data3')
ax.legend()
